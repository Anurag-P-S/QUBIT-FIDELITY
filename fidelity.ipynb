# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
    #At RESONANCE
    #Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath
    


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1


    
"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]
print(H)

for i in range(1,11,1):
    gxr = i/10
    print(gxr)
    print(np.sqrt(gxr))
    print(rho0)
    gzd = 0
    grabi = 0.75*gxr+0.5*gzd
    c_ops = []
    c_ops.append(np.sqrt(gxr) * sigmam())
    #c_ops.append(np.sqrt(gzd) * sigmaz())                 
    #Using the Master Equation Solver
    print(H)
    print('\nc_ops\n')
    print(c_ops)
    print('\nc_ops\n')
    #result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
    result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
    r=result1.states
    print(r[1999])
    f=fidelity(r[1999],rho1)
    print(f)
    #Plotting the probability of excited state
    '''fig, ax = plt.subplots()
    ax.plot(result.times, result.expect[3],'b')
    ax.set_xlabel('Time') 
    ax.set_ylabel('Expectation values') 
    ax.legend(("sigmaz")) 
    sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
    ax.plot(t, sx_analytic, 'k')
    print('\n\n')'''
plt.show()
# Out:
# [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1. 0.]
#  [0. 0.]], [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[0. 0.]
#  [1. 0.]], <function H1_coeff at 0x7fe9104b31f0>], [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[0. 1.]
#  [0. 0.]], <function H2_coeff at 0x7fe9325978b0>]]
# 0.1
# 0.31622776601683794
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1. 0.]
#  [0. 0.]]
# [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1. 0.]
#  [0. 0.]], [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[0. 0.]
#  [1. 0.]], <function H1_coeff at 0x7fe9104b31f0>], [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = False
# Qobj data =
# [[0. 1.]
# ...

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]


for i in range(0,101,1):
    print(i)
    gxr = i/100
    print(gxr)
    gzd = 0
    grabi = 0.75*gxr+0.5*gzd
    c_ops = []
    c_ops.append(np.sqrt(gxr) * sigmam())
    #c_ops.append(np.sqrt(gzd) * sigmaz())                 
    #Using the Master Equation Solver
    result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
    result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
    r=result1.states
    #print(r[1])
    print(fidelity(r[1],rho1))


#Plotting the probability of excited state
'''fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show() '''
# Out:
# 0
# 0.0
# 0.9801060611727812
# 1
# 0.01
# 0.99760289913294
# 2
# 0.02
# 1.053136148811786
# 3
# 0.03
# 1.1499753702763027
# 4
# 0.04
# 1.2942184401718781
# 5
# 0.05
# 1.4952109895150991
# 6
# 0.06
# 1.766179178339891
# 7
# 0.07
# 2.1251508236484917
# 8
# 0.08
# 2.59625935917424
# 9
# 0.09
# 3.2115248236355205
# 10
# 0.1
# 4.013269249590631
# 11
# 0.11
# 5.057319696942226
# 12
# 0.12
# 6.417344972023093
# 13
# 0.13
# 8.19042456878036
# 14
# 0.14
# 10.504861630113295
# 15
# 0.15
# 13.530010667009748
# 16
# 0.16
# 17.489792120016084
# 17
# 0.17
# 22.68045702414157
# 18
# 0.18
# 29.494355918666965
# 19
# 0.19
# 38.452945715066434
# 20
# 0.2
# 50.241390723382196
# 21
# 0.21
# 65.77977927238716
# 22
# 0.22
# 86.28283869818159
# 23
# 0.23
# 113.52163627956135
# 24
# 0.24
# 149.8157538609983
# 25
# 0.25
# 196.60968025289804
# 26
# 0.26
# 262.67037396771616
# 27
# 0.27
# 342.8377766402261
# 28
# 0.28
# 453.6172519058907
# 29
# 0.29
# 637.8747379705025
# 30
# 0.3
# 797.0778999632016
# 31
# ...

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.2
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9776479708122657

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.3
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9673536017313888

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.4
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9576239298483317

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.5
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9484416392751596

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.6

gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9397892929428476

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.7
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9316494416103029

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.8
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
plt.show()
# Out:
# 0.9240045748309137

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.9
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r = result1.states
print(fidelity(r[1999],rho1))


#Plotting the probability of excited state
fig, ax = plt.subplots()
ax.plot(result.times, result.expect[3],'b')
ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 
ax.legend(("sigmaz")) 
sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
#plt.show()
# Out:
# 0.916837627965771

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0.9
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r1 = result1.states
print(fidelity(r1[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#

gxr = 0.8
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result2 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r2 = result1.states
print(fidelity(r2[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.7
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result3 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r3 = result1.states
print(fidelity(r3[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.6
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result4 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r4 = result1.states
print(fidelity(r4[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.5
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result5 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r5 = result1.states
print(fidelity(r5[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.4
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result6 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r6 = result1.states
print(fidelity(r6[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.3
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result7 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r7 = result1.states
print(fidelity(r7[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.2
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result8 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r8 = result1.states
print(fidelity(r8[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0.1
gzd = 0

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result9 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r9 = result1.states
print(fidelity(r9[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#




#Plotting the probability of excited state
#fig, ax = plt.subplots()



#ax.plot(result.times, result.expect[3],'b')



#ax.plot(result.times, result2.expect[3],'g')



#ax.plot(result.times, result3.expect[3],'r')



#ax.plot(result.times, result4.expect[3],'c')



#ax.plot(result.times, result5.expect[3],'m')



#ax.plot(result.times, result6.expect[3],'y')



#ax.plot(result.times, result7.expect[3],'k')



#ax.plot(result.times, result8.expect[3],'w')



#ax.plot(result.times, result9.expect[3],'b')



ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 

sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
#plt.show() 


# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(15)
  
#print("Plot after re-sizing: ")

plt.plot(result.times, result.expect[3],'b')

plt.plot(result.times, result2.expect[3],'g')

plt.plot(result.times, result3.expect[3],'r')

plt.plot(result.times, result4.expect[3],'c')

plt.plot(result.times, result5.expect[3],'m')

plt.plot(result.times, result6.expect[3],'y')

plt.plot(result.times, result7.expect[3],'k')

plt.plot(result.times, result8.expect[3],'w')

plt.plot(result.times, result9.expect[3],'b')


plt.show()
# Out:
# 0.916837627965771
# 0.9240045748309137
# 0.9316494416103029
# 0.9397892929428476
# 0.9484416392751596
# 0.9576239298483317
# 0.9673536017313888
# 0.9776479708122657
# 0.9885243395776466

# %%
#Q2 DRIVEN DAMPED(WITH ONLY RELAXATION) TWO LEVEL SYSTEM
#At RESONANCE
#Using ROTATING WAVE APPROXIMATION


from qutip import *
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import math
import cmath


hbar = 1   #reduced plancks constant choosen to be 1 for convinience
wa = 1      #frequency of the qubit
Wc = 5      #Amplitude of the drive
i = cmath.sqrt(-1)
wc = 1    #frequency of the drive
tpi = np.pi/Wc
t = np.linspace(0.0, tpi, 2000) 

a = basis(2,0) # a is the qubit ground state

ad = a.dag()

rho0 = a*ad #The initial state density matrix

a1 = basis(2,1) # a is the qubit ground state

ad1 = a1.dag()

rho1 = a1*ad1



"""Defining the Hamiltonian"""
H0 = (1+wa*sigmaz())/2 # H is the two level system Hamiltonian

"""By ROTATING WAVE APPROXIMATION used the drive hamiltonian as [sigmaminus*exp(i*wc*t)+sigmaplus*exp(-i*wc*t)]"""
#deifining timedependent coefficients through functions
def H1_coeff(t, args):
    return hbar*Wc*cmath.exp(i*wc*t)/2

def H2_coeff(t, args):
    return hbar*Wc*cmath.exp(-i*wc*t)/2


H1 = sigmam()
H2 = sigmap()

H = [H0,[H1, H1_coeff],[H2, H2_coeff]] #This is the final system hamiltonian including drive
                                         # The drive is given by [H1, H1_coeff],[H2, H2_coeff]




"""Defining the collapse operator"""

gxr = 0
gzd = 0.9

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r1 = result1.states
print(fidelity(r1[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#

gxr = 0
gzd = 0.8

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result2 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r2 = result1.states
print(fidelity(r2[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.7

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result3 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r3 = result1.states
print(fidelity(r3[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.6

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result4 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r4 = result1.states
print(fidelity(r4[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.5

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result5 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r5 = result1.states
print(fidelity(r5[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.4

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result6 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r6 = result1.states
print(fidelity(r6[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.3

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result7 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r7 = result1.states
print(fidelity(r7[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.2

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result8 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r8 = result1.states
print(fidelity(r8[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#


gxr = 0
gzd = 0.1

grabi = 0.75*gxr+0.5*gzd

c_ops = []
c_ops.append(np.sqrt(gxr) * sigmam())
c_ops.append(np.sqrt(gzd) * sigmaz())
        
        
        
                 
#Using the Master Equation Solver
result9 = mesolve(H, rho0, t, c_ops, e_ops=[sigmax(),sigmay(),sigmaz(),rho1], args=None, options=None, progress_bar=None, _safe_mode=True)
result1 = mesolve(H, rho0, t, c_ops, e_ops=None, args=None, options=None, progress_bar=None, _safe_mode=True)
r9 = result1.states
print(fidelity(r9[1999],rho1))

#-------------------------------------------------------------------------------------------------------------------------------------------------#




#Plotting the probability of excited state
#fig, ax = plt.subplots()



#ax.plot(result.times, result.expect[3],'b')



#ax.plot(result.times, result2.expect[3],'g')



#ax.plot(result.times, result3.expect[3],'r')



#ax.plot(result.times, result4.expect[3],'c')



#ax.plot(result.times, result5.expect[3],'m')



#ax.plot(result.times, result6.expect[3],'y')



#ax.plot(result.times, result7.expect[3],'k')



#ax.plot(result.times, result8.expect[3],'w')



#ax.plot(result.times, result9.expect[3],'b')



ax.set_xlabel('Time') 
ax.set_ylabel('Expectation values') 

sx_analytic = (1-(np.cos(Wc*t) * np.exp(-t * gxr)))/2
ax.plot(t, sx_analytic, 'k')
#plt.show() 


# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(15)
  
#print("Plot after re-sizing: ")

plt.plot(result.times, result.expect[3],'b')

plt.plot(result.times, result2.expect[3],'g')

plt.plot(result.times, result3.expect[3],'r')

plt.plot(result.times, result4.expect[3],'c')

plt.plot(result.times, result5.expect[3],'m')

plt.plot(result.times, result6.expect[3],'y')

plt.plot(result.times, result7.expect[3],'k')

plt.plot(result.times, result8.expect[3],'w')

plt.plot(result.times, result9.expect[3],'b')


plt.show()
# Out:
# 0.8837432441460769
# 0.894555686118365
# 0.9058213354580619
# 0.9175683481984402
# 0.9298268629399279
# 0.9426291920283262
# 0.9560097143327047
# 0.9700049193318091
# 0.9846544281560637
